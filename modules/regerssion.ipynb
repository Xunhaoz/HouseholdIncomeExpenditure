# %%
import pandas as pd
import torch
from datetime import datetime
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import torch.nn as nn
import numpy as np
import time
import wandb
import warnings

warnings.filterwarnings('ignore')

# %%
all_df = pd.read_excel(r'..\static\excel\all.xlsx')

# %%
parameters = {
    "regression": 1,
    "time": str(datetime.now()).replace(" ", "_"),
    "model_name": 'linear',
    "learning_rate": 1e-3,
    "epochs": 1000,
    "batch_size": 1024,
    "wandb": False
}

# %%
def init_wandb():
    # start a new wandb run to track this script
    parameters["wandb"] = True
    wandb.init(
        # set the wandb project where this run will be logged
        project="static",

        # track hyperparameters and run metadata
        config={
            "learning_rate": 0.001,
            "architecture": "linearRegression",
            "dataset": "economic",
            "epochs": parameters['epochs'],
        }
    )

init_wandb()
# Out:
# wandb: Currently logged in as: xunhaoz. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.2
# Run data is saved locally in <code>C:\Users\leo20\Desktop\static\modules\wandb\run-20230517_202554-qe0jdsey</code>
# Syncing run <strong><a href='https://wandb.ai/xunhaoz/static/runs/qe0jdsey' target="_blank">faithful-snowball-16</a></strong> to <a href='https://wandb.ai/xunhaoz/static' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xunhaoz/static' target="_blank">https://wandb.ai/xunhaoz/static</a>
#  View run at <a href='https://wandb.ai/xunhaoz/static/runs/qe0jdsey' target="_blank">https://wandb.ai/xunhaoz/static/runs/qe0jdsey</a>

# %%
def preprocess(df):
    df = df.fillna(0)
    df['REL'] = df['REL'].apply(lambda x: 1 if x == 1 else 0)
    df['MALE'] = df['SEX'].apply(lambda x: 1 if x == 1 else 0)
    df['FEMALE'] = df['SEX'].apply(lambda x: 1 if x == 2 else 0)
    df['AGE'] = df['AGE'] / 100
    df['EDU01'] = df['EDU'].apply(lambda x: 1 if x == 1 else 0)
    df['EDU02'] = df['EDU'].apply(lambda x: 1 if x == 2 else 0)
    df['EDU03'] = df['EDU'].apply(lambda x: 1 if x == 3 else 0)
    df['EDU04'] = df['EDU'].apply(lambda x: 1 if x == 4 else 0)
    df['EDU05'] = df['EDU'].apply(lambda x: 1 if x == 5 else 0)
    df['EDU06'] = df['EDU'].apply(lambda x: 1 if x == 6 else 0)
    df['EDU07'] = df['EDU'].apply(lambda x: 1 if x == 7 else 0)
    df['EDU08'] = df['EDU'].apply(lambda x: 1 if x == 8 else 0)
    df['EDU09'] = df['EDU'].apply(lambda x: 1 if x == 9 else 0)
    df['EDU10'] = df['EDU'].apply(lambda x: 1 if x == 10 else 0)
    df['IND00'] = df['IND'].apply(lambda x: 1 if x == 0 else 0)
    df['IND01'] = df['IND'].apply(lambda x: 1 if x == 1 else 0)
    df['IND02'] = df['IND'].apply(lambda x: 1 if x == 2 else 0)
    df['IND03'] = df['IND'].apply(lambda x: 1 if x == 3 else 0)
    df['IND05'] = df['IND'].apply(lambda x: 1 if x == 5 else 0)
    df['IND08'] = df['IND'].apply(lambda x: 1 if x == 8 else 0)
    df['IND35'] = df['IND'].apply(lambda x: 1 if x == 35 else 0)
    df['IND36'] = df['IND'].apply(lambda x: 1 if x == 36 else 0)
    df['IND41'] = df['IND'].apply(lambda x: 1 if x == 41 else 0)
    df['IND45'] = df['IND'].apply(lambda x: 1 if x == 45 else 0)
    df['IND55'] = df['IND'].apply(lambda x: 1 if x == 55 else 0)
    df['IND49'] = df['IND'].apply(lambda x: 1 if x == 49 else 0)
    df['IND58'] = df['IND'].apply(lambda x: 1 if x == 58 else 0)
    df['IND64'] = df['IND'].apply(lambda x: 1 if x == 64 else 0)
    df['IND67'] = df['IND'].apply(lambda x: 1 if x == 67 else 0)
    df['IND69'] = df['IND'].apply(lambda x: 1 if x == 69 else 0)
    df['IND77'] = df['IND'].apply(lambda x: 1 if x == 77 else 0)
    df['IND85'] = df['IND'].apply(lambda x: 1 if x == 85 else 0)
    df['IND86'] = df['IND'].apply(lambda x: 1 if x == 86 else 0)
    df['IND90'] = df['IND'].apply(lambda x: 1 if x == 90 else 0)
    df['IND94'] = df['IND'].apply(lambda x: 1 if x == 94 else 0)
    df['IND83'] = df['IND'].apply(lambda x: 1 if x == 83 else 0)
    df['OCC00'] = df['OCC'].apply(lambda x: 1 if x == 0 else 0)
    df['OCC01'] = df['OCC'].apply(lambda x: 1 if x == 1 else 0)
    df['OCC02'] = df['OCC'].apply(lambda x: 1 if x == 2 else 0)
    df['OCC03'] = df['OCC'].apply(lambda x: 1 if x == 3 else 0)
    df['OCC04'] = df['OCC'].apply(lambda x: 1 if x == 4 else 0)
    df['OCC05'] = df['OCC'].apply(lambda x: 1 if x == 5 else 0)
    df['OCC61'] = df['OCC'].apply(lambda x: 1 if x == 61 else 0)
    df['OCC62'] = df['OCC'].apply(lambda x: 1 if x == 62 else 0)
    df['OCC63'] = df['OCC'].apply(lambda x: 1 if x == 63 else 0)
    df['OCC07'] = df['OCC'].apply(lambda x: 1 if x == 7 else 0)
    df['OCC08'] = df['OCC'].apply(lambda x: 1 if x == 8 else 0)
    df['OCC09'] = df['OCC'].apply(lambda x: 1 if x == 9 else 0)
    df['OCC10'] = df['OCC'].apply(lambda x: 1 if x == 10 else 0)
    df['WKCLASS01'] = df['WKCLASS'].apply(lambda x: 1 if x == 1 else 0)
    df['WKCLASS02'] = df['WKCLASS'].apply(lambda x: 1 if x == 2 else 0)
    df['WKCLASS03'] = df['WKCLASS'].apply(lambda x: 1 if x == 3 else 0)
    df['WKCLASS04'] = df['WKCLASS'].apply(lambda x: 1 if x == 4 else 0)
    df['WKCLASS05'] = df['WKCLASS'].apply(lambda x: 1 if x == 5 else 0)
    df['WKCLASS06'] = df['WKCLASS'].apply(lambda x: 1 if x == 6 else 0)
    df['WKCLASS07'] = df['WKCLASS'].apply(lambda x: 1 if x == 7 else 0)
    df['WKCLASS08'] = df['WKCLASS'].apply(lambda x: 1 if x == 8 else 0)
    df['WKCLASS09'] = df['WKCLASS'].apply(lambda x: 1 if x == 9 else 0)
    df['WORKPLACE02'] = df['WORKPLACE'].apply(lambda x: 1 if x == 2 else 0)
    df['WORKPLACE03'] = df['WORKPLACE'].apply(lambda x: 1 if x == 3 else 0)
    df['WORKPLACE04'] = df['WORKPLACE'].apply(lambda x: 1 if x == 4 else 0)
    df['WORKPLACE05'] = df['WORKPLACE'].apply(lambda x: 1 if x == 5 else 0)
    df['WORKPLACE07'] = df['WORKPLACE'].apply(lambda x: 1 if x == 7 else 0)
    df['WORKPLACE08'] = df['WORKPLACE'].apply(lambda x: 1 if x == 8 else 0)
    df['WORKPLACE09'] = df['WORKPLACE'].apply(lambda x: 1 if x == 9 else 0)
    df['WORKPLACE10'] = df['WORKPLACE'].apply(lambda x: 1 if x == 10 else 0)
    df['WORKPLACE13'] = df['WORKPLACE'].apply(lambda x: 1 if x == 13 else 0)
    df['WORKPLACE14'] = df['WORKPLACE'].apply(lambda x: 1 if x == 14 else 0)
    df['WORKPLACE15'] = df['WORKPLACE'].apply(lambda x: 1 if x == 15 else 0)
    df['WORKPLACE16'] = df['WORKPLACE'].apply(lambda x: 1 if x == 16 else 0)
    df['WORKPLACE17'] = df['WORKPLACE'].apply(lambda x: 1 if x == 17 else 0)
    df['WORKPLACE18'] = df['WORKPLACE'].apply(lambda x: 1 if x == 18 else 0)
    df['WORKPLACE20'] = df['WORKPLACE'].apply(lambda x: 1 if x == 20 else 0)
    df['WORKPLACE63'] = df['WORKPLACE'].apply(lambda x: 1 if x == 63 else 0)
    df['WORKPLACE64'] = df['WORKPLACE'].apply(lambda x: 1 if x == 64 else 0)
    df['WORKPLACE65'] = df['WORKPLACE'].apply(lambda x: 1 if x == 65 else 0)
    df['WORKPLACE66'] = df['WORKPLACE'].apply(lambda x: 1 if x == 66 else 0)
    df['WORKPLACE67'] = df['WORKPLACE'].apply(lambda x: 1 if x == 67 else 0)
    df['WORKPLACE68'] = df['WORKPLACE'].apply(lambda x: 1 if x == 68 else 0)
    df['MRG'] = df['MRG'].apply(lambda x: 0 if x in [91, 93, 94, 95, 96, 97] else 1)
    df['PT'] = df['PT'] - 1

    df = df.drop(
        columns=['YEAR', 'ID', 'PERSON', 'SEX', 'PROV', 'EDU', 'F_EDU', 'DPT', 'IND', 'OCC', 'IND2', 'OCC2', 'ECON',
                 'OUTPATIENT', 'INPATIENT', 'HEALTH_INS', 'HI_PAYER', 'HI_FEE', 'INSURE_ID1', 'INSURE_MONTH1',
                 'INSURE_ID2', 'INSURE_MONTH2', 'DEPENDENTS', 'BIRTH_Y', 'BIRTH_MONTH', 'SRN', 'ROC', 'INC_OLD',
                 'NHICLASS', 'WHOPAY', 'DEPEND', 'SI1CLASS', 'SI1MONTH', 'SI2CLASS', 'SI2MONTH',
                 'WKCLASS', 'WORK', 'WORKPLACE', 'EQUIV']
    )
    return df


preprocessed_df = preprocess(all_df)

# %%
class DataDataset(Dataset):
    def __init__(self, condition_list, salary_list):
        self.condition_list = condition_list
        self.salary_list = salary_list

    def __len__(self):
        return len(self.condition_list)

    def __getitem__(self, index):
        return self.condition_list[index], self.salary_list[index]

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Sequential(
            nn.Linear(82, 512),
            nn.ReLU(),
            nn.Linear(512, 4096),
            nn.ReLU(),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Linear(4096, 1),
        )

    def forward(self, x):
        return self.linear(x)

# %%
train, val = train_test_split(preprocessed_df, train_size=0.8)
train_condition_list = []
train_salary_list = []
val_condition_list = []
val_salary_list = []

for id, row in tqdm(train.iterrows()):
    train_salary_list.append(torch.from_numpy(np.array([row['ITM40'] / 100000])).float())
    train_condition_list.append(torch.from_numpy(row.drop(index=['ITM40']).values).float())

for id, row in tqdm(val.iterrows()):
    val_salary_list.append(torch.from_numpy(np.array([row['ITM40'] / 100000])).float())
    val_condition_list.append(torch.from_numpy(row.drop(index=['ITM40']).values).float())

train_dataset = DataDataset(train_condition_list, train_salary_list)
val_dataset = DataDataset(val_condition_list, val_salary_list)

train_dataloader = DataLoader(train_dataset, batch_size=parameters['batch_size'])
val_dataloader = DataLoader(val_dataset, batch_size=parameters['batch_size'])
# Out:
# 232711it [01:01, 3795.43it/s]
# 58178it [00:15, 3647.49it/s]

# %%
def train(model, data_loader, device, loss_fct, optimizer):
    step_count = train_loss = 0

    for batch_idx, (inputs, labels) in enumerate(data_loader):
        model.train()
        optimizer.zero_grad()
        inputs = inputs.to(device)
        labels = labels.to(device)
        logits = model(inputs)
        loss = loss_fct(logits, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        step_count += 1

    train_loss = train_loss / step_count

    return train_loss

# %%
def evaluate(model, data_loader, device, loss_fct):
    step_count = val_loss = 0
    model.eval()
    with torch.no_grad():
        for batch_idx, (inputs, labels) in enumerate(data_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)
            logits = model(inputs)
            loss = loss_fct(logits, labels)
            val_loss += loss.item()
            step_count += 1

        val_loss = val_loss / step_count

    return val_loss

# %%
def save_checkpoint(save_path, model):
    if save_path is None:
        return
    torch.save(model.state_dict(), save_path)
    print(f'Model saved to ==> {save_path}')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = LinearRegressionModel().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=parameters['learning_rate'], momentum=0.9)
# optimizer = torch.optim.Adam(model.parameters(), lr=parameters['learning_rate'], betas=(0.9, 0.999), eps=1e-9)
loss_fct = torch.nn.MSELoss()

# %%
bestValidLoss = 100
for epoch in range(parameters['epochs']):
    st_time = time.time()
    train_loss = train(model, train_dataloader, device, loss_fct, optimizer)
    val_loss = evaluate(model, val_dataloader, device, loss_fct)

    if val_loss + train_loss < bestValidLoss:
        bestValidLoss = val_loss + train_loss
        save_checkpoint(f'../static/models/CasesModel-Epoch{epoch:03d}.pt', model)

    print('[epoch %d] cost time: %.4f s' % (epoch + 1, time.time() - st_time))
    print('         loss')
    print(f'train | {train_loss: .4f}')
    print(f'val   | {val_loss: .4f}\n')
    if parameters["wandb"]:
        wandb.log({"train_loss": train_loss, "val_loss":val_loss})
# Out:
# Model saved to ==> ../static/models/CasesModel-Epoch000.pt
# [epoch 1] cost time: 12.2342 s
#          loss
# train |  20.2842
# val   |  13.9041
#
# Model saved to ==> ../static/models/CasesModel-Epoch001.pt
# [epoch 2] cost time: 9.6698 s
#          loss
# train |  15.9133
# val   |  13.4039
#
# Model saved to ==> ../static/models/CasesModel-Epoch002.pt
# [epoch 3] cost time: 9.8335 s
#          loss
# train |  15.5317
# val   |  13.1439
#
# Model saved to ==> ../static/models/CasesModel-Epoch003.pt
# [epoch 4] cost time: 9.8259 s
#          loss
# train |  15.3186
# val   |  13.0202
#
# Model saved to ==> ../static/models/CasesModel-Epoch004.pt
# [epoch 5] cost time: 10.2607 s
#          loss
# train |  15.1766
# val   |  12.9640
#
# Model saved to ==> ../static/models/CasesModel-Epoch005.pt
# [epoch 6] cost time: 9.7763 s
#          loss
# train |  15.0657
# val   |  12.9217
#
# Model saved to ==> ../static/models/CasesModel-Epoch006.pt
# [epoch 7] cost time: 10.0005 s
#          loss
# train |  14.9677
# val   |  12.8695
#
# Model saved to ==> ../static/models/CasesModel-Epoch007.pt
# [epoch 8] cost time: 9.7746 s
#          loss
# train |  14.8868
# val   |  12.8335
#
# Model saved to ==> ../static/models/CasesModel-Epoch008.pt
# [epoch 9] cost time: 9.8088 s
#          loss
# train |  14.8203
# val   |  12.7998
#
# Model saved to ==> ../static/models/CasesModel-Epoch009.pt
# [epoch 10] cost time: 9.8096 s
#          loss
# train |  14.7522
# val   |  12.7703
#
# Model saved to ==> ../static/models/CasesModel-Epoch010.pt
# [epoch 11] cost time: 10.0602 s
#          loss
# train |  14.6945
# val   |  12.7462
#
# Model saved to ==> ../static/models/CasesModel-Epoch011.pt
# [epoch 12] cost time: 9.9388 s
#          loss
# train |  14.6489
# val   |  12.7423
#
# Model saved to ==> ../static/models/CasesModel-Epoch012.pt
# [epoch 13] cost time: 9.8540 s
#          loss
# train |  14.6032
# val   |  12.7367
#
# Model saved to ==> ../static/models/CasesModel-Epoch013.pt
# [epoch 14] cost time: 9.7387 s
#          loss
# train |  14.5532
# val   |  12.7629
#
# Model saved to ==> ../static/models/CasesModel-Epoch014.pt
# [epoch 15] cost time: 9.7636 s
#          loss
# train |  14.5127
# val   |  12.7748
#
# Model saved to ==> ../static/models/CasesModel-Epoch015.pt
# [epoch 16] cost time: 9.9186 s
#          loss
# train |  14.4728
# val   |  12.7832
#
# Model saved to ==> ../static/models/CasesModel-Epoch016.pt
# [epoch 17] cost time: 9.7635 s
#          loss
# train |  14.4312
# val   |  12.8068
#
# Model saved to ==> ../static/models/CasesModel-Epoch017.pt
# [epoch 18] cost time: 9.7118 s
#          loss
# train |  14.3877
# val   |  12.8197
#
# Model saved to ==> ../static/models/CasesModel-Epoch018.pt
# [epoch 19] cost time: 9.7114 s
#          loss
# train |  14.3665
# val   |  12.8377
#
# Model saved to ==> ../static/models/CasesModel-Epoch019.pt
# [epoch 20] cost time: 9.7282 s
#          loss
# train |  14.3217
# val   |  12.8823
#
# Model saved to ==> ../static/models/CasesModel-Epoch020.pt
# [epoch 21] cost time: 9.6978 s
#          loss
# train |  14.2938
# val   |  12.9037
#
# Model saved to ==> ../static/models/CasesModel-Epoch021.pt
# [epoch 22] cost time: 9.9421 s
#          loss
# train |  14.2407
# val   |  12.9268
#
# Model saved to ==> ../static/models/CasesModel-Epoch022.pt
# [epoch 23] cost time: 9.8885 s
#          loss
# train |  14.2032
# val   |  12.9056
#
# Model saved to ==> ../static/models/CasesModel-Epoch023.pt
# [epoch 24] cost time: 9.7465 s
#          loss
# train |  14.1556
# val   |  12.9453
#
# Model saved to ==> ../static/models/CasesModel-Epoch024.pt
# [epoch 25] cost time: 9.6681 s
#          loss
# train |  14.1233
# val   |  12.9420
#
# Model saved to ==> ../static/models/CasesModel-Epoch025.pt
# [epoch 26] cost time: 10.0082 s
#          loss
# train |  14.0808
# val   |  12.9386
#
# Model saved to ==> ../static/models/CasesModel-Epoch026.pt
# [epoch 27] cost time: 9.7924 s
#          loss
# train |  14.0319
# val   |  12.9397
#
# Model saved to ==> ../static/models/CasesModel-Epoch027.pt
# [epoch 28] cost time: 10.0256 s
#          loss
# train |  13.9749
# val   |  12.9482
#
# [epoch 29] cost time: 9.5911 s
#          loss
# train |  13.9591
# val   |  12.9657
#
# Model saved to ==> ../static/models/CasesModel-Epoch029.pt
# [epoch 30] cost time: 9.7518 s
#          loss
# train |  13.9034
# val   |  13.0112
#
# Model saved to ==> ../static/models/CasesModel-Epoch030.pt
# [epoch 31] cost time: 9.6879 s
#          loss
# train |  13.8955
# val   |  12.9670
#
# Model saved to ==> ../static/models/CasesModel-Epoch031.pt
# [epoch 32] cost time: 9.7321 s
#          loss
# train |  13.8380
# val   |  13.0076
#
# Model saved to ==> ../static/models/CasesModel-Epoch032.pt
# [epoch 33] cost time: 9.9504 s
#          loss
# train |  13.8164
# val   |  12.9713
#
# Model saved to ==> ../static/models/CasesModel-Epoch033.pt
# [epoch 34] cost time: 9.9577 s
#          loss
# train |  13.7460
# val   |  13.0227
#
# [epoch 35] cost time: 9.5449 s
#          loss
# train |  13.7507
# val   |  13.0391
#
# Model saved to ==> ../static/models/CasesModel-Epoch035.pt
# [epoch 36] cost time: 9.6706 s
#          loss
# train |  13.6989
# val   |  13.0328
#
# Model saved to ==> ../static/models/CasesModel-Epoch036.pt
# [epoch 37] cost time: 9.6984 s
#          loss
# train |  13.6801
# val   |  13.0385
#
# Model saved to ==> ../static/models/CasesModel-Epoch037.pt
# [epoch 38] cost time: 9.6757 s
#          loss
# train |  13.6755
# val   |  13.0020
#
# Model saved to ==> ../static/models/CasesModel-Epoch038.pt
# [epoch 39] cost time: 9.6515 s
#          loss
# train |  13.6429
# val   |  12.9869
#
# [epoch 40] cost time: 9.7159 s
#          loss
# train |  13.5832
# val   |  13.0703
#
# Model saved to ==> ../static/models/CasesModel-Epoch040.pt
# [epoch 41] cost time: 9.6603 s
#          loss
# train |  13.5426
# val   |  13.0836
#
# [epoch 42] cost time: 9.5543 s
#          loss
# train |  13.5768
# val   |  13.0652
#
# Model saved to ==> ../static/models/CasesModel-Epoch042.pt
# [epoch 43] cost time: 9.7012 s
#          loss
# train |  13.6072
# val   |  12.9910
#
# Model saved to ==> ../static/models/CasesModel-Epoch043.pt
# [epoch 44] cost time: 9.6650 s
#          loss
# train |  13.5431
# val   |  13.0263
#
# [epoch 45] cost time: 9.7746 s
#          loss
# train |  13.5388
# val   |  13.0722
#
# [epoch 46] cost time: 9.5151 s
#          loss
# train |  13.4360
# val   |  13.1500
#
# [epoch 47] cost time: 9.5488 s
#          loss
# train |  13.5194
# val   |  13.1253
#
# [epoch 48] cost time: 9.6350 s
#          loss
# train |  13.4817
# val   |  13.1271
#
# [epoch 49] cost time: 9.5373 s
#          loss
# train |  13.4485
# val   |  13.1396
#
# Model saved to ==> ../static/models/CasesModel-Epoch049.pt
# [epoch 50] cost time: 10.0334 s
#          loss
# train |  13.4004
# val   |  13.1530
#
# Model saved to ==> ../static/models/CasesModel-Epoch050.pt
# [epoch 51] cost time: 10.0283 s
#          loss
# train |  13.4023
# val   |  13.1352
#
# Model saved to ==> ../static/models/CasesModel-Epoch051.pt
# [epoch 52] cost time: 9.6576 s
#          loss
# train |  13.2551
# val   |  13.1301
#
# [epoch 53] cost time: 9.4822 s
#          loss
# train |  13.2496
# val   |  13.1685
#
# [epoch 54] cost time: 9.5055 s
#          loss
# train |  13.2503
# val   |  13.2697
#
# [epoch 55] cost time: 9.4944 s
#          loss
# train |  13.2741
# val   |  13.2776
#
# [epoch 56] cost time: 9.4822 s
#          loss
# train |  13.3084
# val   |  13.2232
#
# [epoch 57] cost time: 9.7452 s
#          loss
# train |  13.3161
# val   |  13.1196
#
# Model saved to ==> ../static/models/CasesModel-Epoch057.pt
# [epoch 58] cost time: 9.7745 s
#          loss
# train |  13.1848
# val   |  13.0908
#
# Model saved to ==> ../static/models/CasesModel-Epoch058.pt
# [epoch 59] cost time: 9.7681 s
#          loss
# train |  13.1208
# val   |  13.1350
#
# [epoch 60] cost time: 9.7704 s
#          loss
# train |  13.0679
# val   |  13.2496
#
# Model saved to ==> ../static/models/CasesModel-Epoch060.pt
# [epoch 61] cost time: 9.9034 s
#          loss
# train |  12.9696
# val   |  13.2515
#
# [epoch 62] cost time: 9.5515 s
#          loss
# train |  12.9785
# val   |  13.2710
#
# Model saved to ==> ../static/models/CasesModel-Epoch062.pt
# [epoch 63] cost time: 10.0006 s
#          loss
# train |  12.8972
# val   |  13.2974
#
# Model saved to ==> ../static/models/CasesModel-Epoch063.pt
# [epoch 64] cost time: 9.6667 s
#          loss
# train |  12.8433
# val   |  13.3502
#
# [epoch 65] cost time: 9.4527 s
#          loss
# train |  12.8068
# val   |  13.3955
#
# Model saved to ==> ../static/models/CasesModel-Epoch065.pt
# [epoch 66] cost time: 9.7138 s
#          loss
# train |  12.7043
# val   |  13.3824
#
# Model saved to ==> ../static/models/CasesModel-Epoch066.pt
# [epoch 67] cost time: 9.6633 s
#          loss
# train |  12.5781
# val   |  13.4915
#
# Model saved to ==> ../static/models/CasesModel-Epoch067.pt
# [epoch 68] cost time: 9.8161 s
#          loss
# train |  12.5667
# val   |  13.4540
#
# Model saved to ==> ../static/models/CasesModel-Epoch068.pt
# [epoch 69] cost time: 9.5739 s
#          loss
# train |  12.4605
# val   |  13.4547
#
# [epoch 70] cost time: 9.4775 s
#          loss
# train |  12.4598
# val   |  13.5152
#
# Model saved to ==> ../static/models/CasesModel-Epoch070.pt
# [epoch 71] cost time: 9.6067 s
#          loss
# train |  12.3829
# val   |  13.5236
#
# [epoch 72] cost time: 9.4854 s
#          loss
# train |  12.3718
# val   |  13.5832
#
# Model saved to ==> ../static/models/CasesModel-Epoch072.pt
# [epoch 73] cost time: 9.5638 s
#          loss
# train |  12.3582
# val   |  13.4700
#
# Model saved to ==> ../static/models/CasesModel-Epoch073.pt
# [epoch 74] cost time: 9.7367 s
#          loss
# train |  12.2830
# val   |  13.4995
#
# Model saved to ==> ../static/models/CasesModel-Epoch074.pt
# [epoch 75] cost time: 9.5243 s
#          loss
# train |  12.2698
# val   |  13.4491
#
# [epoch 76] cost time: 9.4261 s
#          loss
# train |  12.2197
# val   |  13.6113
#
# [epoch 77] cost time: 9.4348 s
#          loss
# train |  12.2082
# val   |  13.5701
#
# [epoch 78] cost time: 9.4027 s
#          loss
# train |  12.1541
# val   |  13.6032
#
# Model saved to ==> ../static/models/CasesModel-Epoch078.pt
# [epoch 79] cost time: 9.5717 s
#          loss
# train |  12.0900
# val   |  13.6167
#
# [epoch 80] cost time: 9.6511 s
#          loss
# train |  11.9996
# val   |  13.7073
#
# Model saved to ==> ../static/models/CasesModel-Epoch080.pt
# [epoch 81] cost time: 9.5005 s
#          loss
# train |  11.9905
# val   |  13.6915
#
# Model saved to ==> ../static/models/CasesModel-Epoch081.pt
# [epoch 82] cost time: 9.4742 s
#          loss
# train |  11.9840
# val   |  13.6743
#
# Model saved to ==> ../static/models/CasesModel-Epoch082.pt
# [epoch 83] cost time: 9.4601 s
#          loss
# train |  11.9419
# val   |  13.7159
#
# Model saved to ==> ../static/models/CasesModel-Epoch083.pt
# [epoch 84] cost time: 9.5180 s
#          loss
# train |  11.8636
# val   |  13.7397
#
# [epoch 85] cost time: 9.3934 s
#          loss
# train |  11.8758
# val   |  13.8192
#
# [epoch 86] cost time: 9.6362 s
#          loss
# train |  11.7842
# val   |  13.8724
#
# [epoch 87] cost time: 9.3666 s
#          loss
# train |  11.6893
# val   |  13.9696
#
# [epoch 88] cost time: 9.3527 s
#          loss
# train |  11.7419
# val   |  13.8681
#
# [epoch 89] cost time: 9.3722 s
#          loss
# train |  11.7326
# val   |  13.9964
#
# [epoch 90] cost time: 9.3425 s
#          loss
# train |  11.7146
# val   |  13.9351
#
# [epoch 91] cost time: 9.3502 s
#          loss
# train |  11.6199
# val   |  14.0760
#
# Model saved to ==> ../static/models/CasesModel-Epoch091.pt
# [epoch 92] cost time: 9.7004 s
#          loss
# train |  11.5785
# val   |  13.9600
#
# [epoch 93] cost time: 9.3463 s
#          loss
# train |  11.6169
# val   |  14.0707
#
# Model saved to ==> ../static/models/CasesModel-Epoch093.pt
# [epoch 94] cost time: 9.4564 s
#          loss
# train |  11.5844
# val   |  13.9167
#
# [epoch 95] cost time: 9.3393 s
#          loss
# train |  11.5442
# val   |  14.1188
#
# [epoch 96] cost time: 9.3337 s
#          loss
# train |  11.4966
# val   |  14.0873
#
# Model saved to ==> ../static/models/CasesModel-Epoch096.pt
# [epoch 97] cost time: 9.6773 s
#          loss
# train |  11.3148
# val   |  14.1253
#
# Model saved to ==> ../static/models/CasesModel-Epoch097.pt
# [epoch 98] cost time: 9.4711 s
#          loss
# train |  11.3761
# val   |  13.9681
#
# Model saved to ==> ../static/models/CasesModel-Epoch098.pt
# [epoch 99] cost time: 9.4596 s
#          loss
# train |  11.3791
# val   |  13.9340
#
# Model saved to ==> ../static/models/CasesModel-Epoch099.pt
# [epoch 100] cost time: 9.4747 s
#          loss
# train |  11.2757
# val   |  13.9665
#
# [epoch 101] cost time: 9.3308 s
#          loss
# train |  11.5343
# val   |  14.0177
#
# [epoch 102] cost time: 9.3704 s
#          loss
# train |  11.4043
# val   |  14.0300
#
# [epoch 103] cost time: 9.5910 s
#          loss
# train |  11.5948
# val   |  14.0081
#
# [epoch 104] cost time: 9.3632 s
#          loss
# train |  11.3367
# val   |  13.9824
#
# [epoch 105] cost time: 9.3468 s
#          loss
# train |  11.3178
# val   |  14.0273
#
# [epoch 106] cost time: 9.3661 s
#          loss
# train |  11.2435
# val   |  14.0018
#
# [epoch 107] cost time: 9.4890 s
#          loss
# train |  11.1837
# val   |  14.0586
#
# Model saved to ==> ../static/models/CasesModel-Epoch107.pt
# [epoch 108] cost time: 9.6288 s
#          loss
# train |  11.0470
# val   |  14.0279
#
# [epoch 109] cost time: 9.7286 s
#          loss
# train |  11.0388
# val   |  14.0657
#
# [epoch 110] cost time: 9.3716 s
#          loss
# train |  11.0531
# val   |  14.1467
#
# Model saved to ==> ../static/models/CasesModel-Epoch110.pt
# [epoch 111] cost time: 9.4608 s
#          loss
# train |  11.0238
# val   |  14.0386
#
# [epoch 112] cost time: 9.3166 s
#          loss
# train |  11.0759
# val   |  14.1170
#
# [epoch 113] cost time: 9.3198 s
#          loss
# train |  11.0440
# val   |  14.1676
#
# [epoch 114] cost time: 9.3366 s
#          loss
# train |  11.0765
# val   |  14.0306
#
# [epoch 115] cost time: 9.5304 s
#          loss
# train |  11.1608
# val   |  13.9932
#
# [epoch 116] cost time: 9.3241 s
#          loss
# train |  11.2943
# val   |  14.0615
#
# [epoch 117] cost time: 9.3156 s
#          loss
# train |  11.2471
# val   |  13.9472
#
# [epoch 118] cost time: 9.3245 s
#          loss
# train |  11.1067
# val   |  14.0411
#
# Model saved to ==> ../static/models/CasesModel-Epoch118.pt
# [epoch 119] cost time: 9.4726 s
#          loss
# train |  11.0642
# val   |  13.9005
#
# [epoch 120] cost time: 9.3106 s
#          loss
# train |  11.0180
# val   |  13.9531
#
# Model saved to ==> ../static/models/CasesModel-Epoch120.pt
# [epoch 121] cost time: 9.6658 s
#          loss
# train |  10.8804
# val   |  13.7947
#
# [epoch 122] cost time: 9.3358 s
#          loss
# train |  10.8877
# val   |  13.8767
#
# [epoch 123] cost time: 9.3305 s
#          loss
# train |  10.9662
# val   |  14.0602
#
# [epoch 124] cost time: 9.3373 s
#          loss
# train |  10.9617
# val   |  13.8647
#
# [epoch 125] cost time: 9.3162 s
#          loss
# train |  11.0038
# val   |  13.9414
#
# Model saved to ==> ../static/models/CasesModel-Epoch125.pt
# [epoch 126] cost time: 9.6687 s
#          loss
# train |  10.8000
# val   |  13.8582
#
# [epoch 127] cost time: 9.3213 s
#          loss
# train |  10.8893
# val   |  14.1300
#
# [epoch 128] cost time: 9.3232 s
#          loss
# train |  10.7598
# val   |  13.9977
#
# [epoch 129] cost time: 9.3395 s
#          loss
# train |  10.7542
# val   |  13.9363
#
# [epoch 130] cost time: 9.3299 s
#          loss
# train |  10.7160
# val   |  13.9626
#
# [epoch 131] cost time: 9.3254 s
#          loss
# train |  10.7932
# val   |  14.0873
#
# [epoch 132] cost time: 9.7584 s
#          loss
# train |  10.8085
# val   |  14.0585
#
# [epoch 133] cost time: 9.3236 s
#          loss
# train |  10.7863
# val   |  14.0625
#
# [epoch 134] cost time: 9.3068 s
#          loss
# train |  10.8698
# val   |  14.2737
#
# [epoch 135] cost time: 9.3200 s
#          loss
# train |  10.8341
# val   |  14.1943
#
# [epoch 136] cost time: 9.5305 s
#          loss
# train |  10.8656
# val   |  14.0219
#
# [epoch 137] cost time: 9.3393 s
#          loss
# train |  10.7261
# val   |  14.1770
#
# [epoch 138] cost time: 9.5307 s
#          loss
# train |  10.8119
# val   |  14.2150
#
# [epoch 139] cost time: 9.5488 s
#          loss
# train |  10.6964
# val   |  14.0629
#
# [epoch 140] cost time: 9.5463 s
#          loss
# train |  10.6323
# val   |  14.2643
#
# [epoch 141] cost time: 9.3279 s
#          loss
# train |  10.5714
# val   |  14.1525
#
# [epoch 142] cost time: 9.3303 s
#          loss
# train |  10.6321
# val   |  14.4211
#
# Model saved to ==> ../static/models/CasesModel-Epoch142.pt
# [epoch 143] cost time: 9.4646 s
#          loss
# train |  10.4508
# val   |  14.0051
#
# [epoch 144] cost time: 9.5293 s
#          loss
# train |  10.4604
# val   |  14.4014
#
# [epoch 145] cost time: 9.3141 s
#          loss
# train |  10.3789
# val   |  14.2648
#
# [epoch 146] cost time: 9.3111 s
#          loss
# train |  10.3676
# val   |  14.5174
#
# [epoch 147] cost time: 9.3235 s
#          loss
# train |  10.5442
# val   |  14.4956
#
# [epoch 148] cost time: 9.3206 s
#          loss
# train |  10.6098
# val   |  14.3689
#
# [epoch 149] cost time: 9.3143 s
#          loss
# train |  10.6548
# val   |  14.3887
#
# [epoch 150] cost time: 9.5493 s
#          loss
# train |  10.5271
# val   |  14.1825
#
# [epoch 151] cost time: 9.3116 s
#          loss
# train |  10.5377
# val   |  14.3970
#
# [epoch 152] cost time: 9.3250 s
#          loss
# train |  10.4776
# val   |  14.2512
#
# [epoch 153] cost time: 9.3258 s
#          loss
# train |  10.5287
# val   |  14.4871
#
# [epoch 154] cost time: 9.3464 s
#          loss
# train |  10.3618
# val   |  14.4452
#
# [epoch 155] cost time: 9.5258 s
#          loss
# train |  10.4514
# val   |  14.1018
#
# [epoch 156] cost time: 9.3274 s
#          loss
# train |  10.4620
# val   |  14.7723
#
# [epoch 157] cost time: 9.3173 s
#          loss
# train |  10.4991
# val   |  14.4410
#
# [epoch 158] cost time: 9.3266 s
#          loss
# train |  10.3726
# val   |  14.1487
#
# [epoch 159] cost time: 9.3300 s
#          loss
# train |  10.2283
# val   |  14.8174
#
# [epoch 160] cost time: 9.3257 s
#          loss
# train |  10.1835
# val   |  14.7036
#
# [epoch 161] cost time: 9.5309 s
#          loss
# train |  10.1209
# val   |  14.5775
#
# [epoch 162] cost time: 9.3231 s
#          loss
# train |  10.1601
# val   |  14.4228
#
# [epoch 163] cost time: 9.3280 s
#          loss
# train |  10.0700
# val   |  14.7381
#
# [epoch 164] cost time: 9.3426 s
#          loss
# train |  10.0812
# val   |  14.7478
#
# [epoch 165] cost time: 9.3296 s
#          loss
# train |  10.0790
# val   |  14.8652
#
# [epoch 166] cost time: 9.3356 s
#          loss
# train |  10.0790
# val   |  14.7156
#
# [epoch 167] cost time: 9.5566 s
#          loss
# train |  10.1544
# val   |  15.0271
#
# [epoch 168] cost time: 9.3427 s
#          loss
# train |  10.2716
# val   |  14.4025
#
# [epoch 169] cost time: 9.3624 s
#          loss
# train |  10.1626
# val   |  14.6357
#
# [epoch 170] cost time: 9.3427 s
#          loss
# train |  10.1709
# val   |  14.5945
#
# [epoch 171] cost time: 9.3321 s
#          loss
# train |  10.0975
# val   |  14.6330
#
# Model saved to ==> ../static/models/CasesModel-Epoch171.pt
# [epoch 172] cost time: 9.4510 s
#          loss
# train |  9.9431
# val   |  14.4393
#
# [epoch 173] cost time: 9.5498 s
#          loss
# train |  9.9296
# val   |  14.8500
#
# [epoch 174] cost time: 9.3400 s
#          loss
# train |  10.1662
# val   |  14.9936
#
# [epoch 175] cost time: 9.3310 s
#          loss
# train |  10.3006
# val   |  14.8316
#
# [epoch 176] cost time: 9.3177 s
#          loss
# train |  10.0819
# val   |  14.4218
#
# [epoch 177] cost time: 9.3068 s
#          loss
# train |  10.1014
# val   |  14.6031
#
# [epoch 178] cost time: 9.3332 s
#          loss
# train |  9.9661
# val   |  14.6349
#
# [epoch 179] cost time: 9.5637 s
#          loss
# train |  9.9534
# val   |  14.6302
#
# [epoch 180] cost time: 9.3405 s
#          loss
# train |  9.9151
# val   |  14.7006
#
# [epoch 181] cost time: 9.3456 s
#          loss
# train |  9.8625
# val   |  14.7149
#
# [epoch 182] cost time: 9.3636 s
#          loss
# train |  9.7616
# val   |  14.7986
#
# [epoch 183] cost time: 9.3765 s
#          loss
# train |  9.8930
# val   |  15.0035
#
# [epoch 184] cost time: 9.6017 s
#          loss
# train |  9.7847
# val   |  14.7836
#
# [epoch 185] cost time: 9.3976 s
#          loss
# train |  9.7694
# val   |  15.0171
#
# [epoch 186] cost time: 9.3677 s
#          loss
# train |  9.8483
# val   |  15.1683
#
# [epoch 187] cost time: 9.6369 s
#          loss
# train |  9.9074
# val   |  15.0760
#
# [epoch 188] cost time: 9.3978 s
#          loss
# train |  9.9088
# val   |  14.8707
#
# [epoch 189] cost time: 9.3323 s
#          loss
# train |  9.8301
# val   |  15.1294
#
# [epoch 190] cost time: 9.5575 s
#          loss
# train |  9.9190
# val   |  14.9692
#
# [epoch 191] cost time: 9.3277 s
#          loss
# train |  9.8683
# val   |  14.7753
#
# [epoch 192] cost time: 9.3601 s
#          loss
# train |  9.8688
# val   |  14.9278
#
# [epoch 193] cost time: 9.3531 s
#          loss
# train |  9.8209
# val   |  15.5692
#
# [epoch 194] cost time: 9.3516 s
#          loss
# train |  9.7656
# val   |  15.0280
#
# [epoch 195] cost time: 9.3559 s
#          loss
# train |  9.7064
# val   |  15.0231
#
# [epoch 196] cost time: 9.5686 s
#          loss
# train |  9.5792
# val   |  15.2479
#
# [epoch 197] cost time: 9.3447 s
#          loss
# train |  9.6334
# val   |  15.3592
#
# [epoch 198] cost time: 9.3273 s
#          loss
# train |  9.9510
# val   |  14.7777
#
# [epoch 199] cost time: 9.3610 s
#          loss
# train |  9.7994
# val   |  15.0005
#
# [epoch 200] cost time: 9.3448 s
#          loss
# train |  9.7006
# val   |  14.9352
#
# [epoch 201] cost time: 9.3586 s
#          loss
# train |  9.5662
# val   |  15.0604
#
# [epoch 202] cost time: 9.5713 s
#          loss
# train |  9.6799
# val   |  14.9610
#
# [epoch 203] cost time: 9.3478 s
#          loss
# train |  9.6901
# val   |  15.0775
#
# [epoch 204] cost time: 9.3541 s
#          loss
# train |  9.7753
# val   |  15.1830
#
# [epoch 205] cost time: 9.3513 s
#          loss
# train |  9.7689
# val   |  14.6797
#
# [epoch 206] cost time: 9.4833 s
#          loss
# train |  9.7888
# val   |  15.2100
#
# [epoch 207] cost time: 9.6134 s
#          loss
# train |  9.7648
# val   |  14.9858
#
# [epoch 208] cost time: 9.3890 s
#          loss
# train |  9.6040
# val   |  15.1088
#
# [epoch 209] cost time: 9.3649 s
#          loss
# train |  9.4524
# val   |  15.1191
#
# [epoch 210] cost time: 9.3697 s
#          loss
# train |  9.4055
# val   |  15.0488
#
# [epoch 211] cost time: 9.3614 s
#          loss
# train |  9.4035
# val   |  15.3261
#
# [epoch 212] cost time: 9.3577 s
#          loss
# train |  9.3568
# val   |  15.3784
#
# [epoch 213] cost time: 9.5933 s
#          loss
# train |  9.3854
# val   |  15.3154
#
# [epoch 214] cost time: 9.3543 s
#          loss
# train |  9.5464
# val   |  15.2106
#
# [epoch 215] cost time: 9.3576 s
#          loss
# train |  9.5231
# val   |  15.5027
#
# [epoch 216] cost time: 9.3400 s
#          loss
# train |  9.4494
# val   |  15.2609
#
# [epoch 217] cost time: 9.3630 s
#          loss
# train |  9.7124
# val   |  15.2672
#
# [epoch 218] cost time: 9.3798 s
#          loss
# train |  9.5941
# val   |  15.2019
#
# [epoch 219] cost time: 9.5867 s
#          loss
# train |  9.5675
# val   |  14.8369
#
# Model saved to ==> ../static/models/CasesModel-Epoch219.pt
# [epoch 220] cost time: 9.6277 s
#          loss
# train |  9.5410
# val   |  14.7488
#
# [epoch 221] cost time: 9.3507 s
#          loss
# train |  9.7372
# val   |  14.8676
#
# Model saved to ==> ../static/models/CasesModel-Epoch221.pt
# [epoch 222] cost time: 9.4975 s
#          loss
# train |  9.5593
# val   |  14.5240
#
# [epoch 223] cost time: 9.3443 s
#          loss
# train |  9.5031
# val   |  14.7117
#
# [epoch 224] cost time: 9.3480 s
#          loss
# train |  9.5160
# val   |  14.8538
#
# [epoch 225] cost time: 9.5789 s
#          loss
# train |  9.5351
# val   |  14.6473
#
# Model saved to ==> ../static/models/CasesModel-Epoch225.pt
# [epoch 226] cost time: 9.4696 s
#          loss
# train |  9.3218
# val   |  14.5448
#
# Model saved to ==> ../static/models/CasesModel-Epoch226.pt
# [epoch 227] cost time: 9.4757 s
#          loss
# train |  9.2122
# val   |  14.6188
#
# Model saved to ==> ../static/models/CasesModel-Epoch227.pt
# [epoch 228] cost time: 9.4681 s
#          loss
# train |  9.1215
# val   |  14.5825
#
# [epoch 229] cost time: 9.3515 s
#          loss
# train |  9.0787
# val   |  14.8193
#
# [epoch 230] cost time: 9.3589 s
#          loss
# train |  9.2160
# val   |  14.5125
#
# [epoch 231] cost time: 9.5791 s
#          loss
# train |  9.2491
# val   |  14.9827
#
# [epoch 232] cost time: 9.3596 s
#          loss
# train |  9.3894
# val   |  14.9820
#
# [epoch 233] cost time: 9.3607 s
#          loss
# train |  9.2628
# val   |  14.8537
#
# [epoch 234] cost time: 9.3801 s
#          loss
# train |  9.3646
# val   |  14.4829
#
# [epoch 235] cost time: 9.3666 s
#          loss
# train |  9.3293
# val   |  14.9992
#
# [epoch 236] cost time: 9.5753 s
#          loss
# train |  9.2345
# val   |  14.9261
#
# [epoch 237] cost time: 9.3658 s
#          loss
# train |  9.1384
# val   |  14.8327
#
# [epoch 238] cost time: 9.3720 s
#          loss
# train |  9.1648
# val   |  14.9775
#
# [epoch 239] cost time: 9.3694 s
#          loss
# train |  9.0750
# val   |  14.8545
#
# [epoch 240] cost time: 9.3325 s
#          loss
# train |  9.0393
# val   |  14.9394
#
# [epoch 241] cost time: 9.3584 s
#          loss
# train |  8.9758
# val   |  15.0052
#
# [epoch 242] cost time: 9.5698 s
#          loss
# train |  9.1735
# val   |  14.6126
#
# [epoch 243] cost time: 9.3562 s
#          loss
# train |  9.1268
# val   |  15.0125
#
# [epoch 244] cost time: 9.3735 s
#          loss
# train |  9.2062
# val   |  14.9068
#
# [epoch 245] cost time: 9.3487 s
#          loss
# train |  9.1365
# val   |  15.1370
#
# [epoch 246] cost time: 9.3478 s
#          loss
# train |  9.3258
# val   |  15.1224
#
# [epoch 247] cost time: 9.3581 s
#          loss
# train |  9.5499
# val   |  15.1011
#
# [epoch 248] cost time: 9.5760 s
#          loss
# train |  9.4333
# val   |  15.0415
#
# [epoch 249] cost time: 9.3406 s
#          loss
# train |  9.2047
# val   |  14.7447
#
# [epoch 250] cost time: 9.3642 s
#          loss
# train |  9.0806
# val   |  14.8147
#
# [epoch 251] cost time: 9.3561 s
#          loss
# train |  8.9941
# val   |  14.9105
#
# [epoch 252] cost time: 9.3429 s
#          loss
# train |  8.9326
# val   |  15.2129
#
# [epoch 253] cost time: 9.3492 s
#          loss
# train |  9.0866
# val   |  14.8118
#
# [epoch 254] cost time: 9.5611 s
#          loss
# train |  9.0203
# val   |  14.7251
#
# [epoch 255] cost time: 9.3580 s
#          loss
# train |  8.8939
# val   |  14.8571
#
# Model saved to ==> ../static/models/CasesModel-Epoch255.pt
# [epoch 256] cost time: 9.4933 s
#          loss
# train |  8.9423
# val   |  14.4833
#
# [epoch 257] cost time: 9.3581 s
#          loss
# train |  9.1279
# val   |  14.6418
#
# [epoch 258] cost time: 9.3896 s
#          loss
# train |  9.1091
# val   |  14.9156
#
# [epoch 259] cost time: 9.3620 s
#          loss
# train |  8.9440
# val   |  14.5065
#
# [epoch 260] cost time: 9.5650 s
#          loss
# train |  8.9130
# val   |  14.9796
#
# [epoch 261] cost time: 9.3415 s
#          loss
# train |  8.8826
# val   |  15.1898
#
# [epoch 262] cost time: 9.3727 s
#          loss
# train |  8.7762
# val   |  15.0369
#
# [epoch 263] cost time: 9.3525 s
#          loss
# train |  8.7853
# val   |  14.7973
#
# [epoch 264] cost time: 9.3567 s
#          loss
# train |  8.9071
# val   |  14.9264
#
# [epoch 265] cost time: 9.5808 s
#          loss
# train |  9.1456
# val   |  15.0988
#
# [epoch 266] cost time: 9.3524 s
#          loss
# train |  8.9574
# val   |  15.0770
#
# [epoch 267] cost time: 9.3351 s
#          loss
# train |  8.9385
# val   |  15.4356
#
# [epoch 268] cost time: 9.3283 s
#          loss
# train |  8.8983
# val   |  15.3388
#
# [epoch 269] cost time: 9.3557 s
#          loss
# train |  8.9167
# val   |  15.0139
#
# [epoch 270] cost time: 9.3626 s
#          loss
# train |  8.9701
# val   |  15.1151
#
# [epoch 271] cost time: 9.5682 s
#          loss
# train |  8.9342
# val   |  15.2166
#
# [epoch 272] cost time: 9.3255 s
#          loss
# train |  8.7973
# val   |  15.5556
#
# [epoch 273] cost time: 9.3358 s
#          loss
# train |  8.9526
# val   |  15.4251
#
# [epoch 274] cost time: 9.3509 s
#          loss
# train |  8.9563
# val   |  14.9569
#
# [epoch 275] cost time: 9.3451 s
#          loss
# train |  8.9423
# val   |  14.8316
#
# [epoch 276] cost time: 9.3615 s
#          loss
# train |  9.0385
# val   |  14.6386
#
# [epoch 277] cost time: 9.5604 s
#          loss
# train |  9.2880
# val   |  14.8086
#
# [epoch 278] cost time: 9.3193 s
#          loss
# train |  9.2497
# val   |  14.7195
#
# [epoch 279] cost time: 9.3413 s
#          loss
# train |  9.3269
# val   |  14.6758
#
# [epoch 280] cost time: 9.3348 s
#          loss
# train |  9.2422
# val   |  14.7056
#
# [epoch 281] cost time: 9.3505 s
#          loss
# train |  9.1114
# val   |  14.6839
#
# [epoch 282] cost time: 9.3534 s
#          loss
# train |  8.9891
# val   |  14.9115
#
# [epoch 283] cost time: 9.5582 s
#          loss
# train |  9.2190
# val   |  14.9350
#
# [epoch 284] cost time: 9.3268 s
#          loss
# train |  9.0875
# val   |  15.0432
#
# [epoch 285] cost time: 9.4145 s
#          loss
# train |  9.1817
# val   |  14.8835
#
# [epoch 286] cost time: 9.4208 s
#          loss
# train |  9.1626
# val   |  15.2920
#
# [epoch 287] cost time: 9.3492 s
#          loss
# train |  8.9961
# val   |  15.2600
#
# [epoch 288] cost time: 9.3412 s
#          loss
# train |  8.9673
# val   |  15.4625
#
# [epoch 289] cost time: 9.5765 s
#          loss
# train |  8.8740
# val   |  15.1441
#
# [epoch 290] cost time: 9.3586 s
#          loss
# train |  8.8050
# val   |  15.0647
#
# [epoch 291] cost time: 9.3596 s
#          loss
# train |  8.8752
# val   |  15.0643
#
# [epoch 292] cost time: 9.3403 s
#          loss
# train |  8.9984
# val   |  14.9568
#
# [epoch 293] cost time: 9.3392 s
#          loss
# train |  9.1651
# val   |  15.0792
#
# [epoch 294] cost time: 9.5561 s
#          loss
# train |  9.0442
# val   |  15.2278
#
# [epoch 295] cost time: 9.3627 s
#          loss
# train |  9.1223
# val   |  15.3658
#
# [epoch 296] cost time: 9.3466 s
#          loss
# train |  9.2386
# val   |  15.2697
#
# [epoch 297] cost time: 9.3472 s
#          loss
# train |  9.1235
# val   |  15.1786
#
# [epoch 298] cost time: 9.3251 s
#          loss
# train |  9.0691
# val   |  15.2842
#
# [epoch 299] cost time: 9.3414 s
#          loss
# train |  8.9206
# val   |  15.0586
#
# [epoch 300] cost time: 9.5707 s
#          loss
# train |  8.7871
# val   |  15.1199
#
# [epoch 301] cost time: 9.3312 s
#          loss
# train |  8.7505
# val   |  15.2706
#
# [epoch 302] cost time: 9.3358 s
#          loss
# train |  8.6993
# val   |  15.1413
#
# [epoch 303] cost time: 9.3399 s
#          loss
# train |  8.9216
# val   |  15.3721
#
# [epoch 304] cost time: 9.3549 s
#          loss
# train |  8.8426
# val   |  15.3284
#
# [epoch 305] cost time: 9.3535 s
#          loss
# train |  8.7154
# val   |  15.3306
#
# [epoch 306] cost time: 9.5730 s
#          loss
# train |  8.7465
# val   |  15.1653
#
# [epoch 307] cost time: 9.3635 s
#          loss
# train |  9.0834
# val   |  15.5158
#
# [epoch 308] cost time: 9.3469 s
#          loss
# train |  8.9847
# val   |  15.3666
#
# [epoch 309] cost time: 9.3520 s
#          loss
# train |  8.9286
# val   |  15.5333
#
# [epoch 310] cost time: 9.3369 s
#          loss
# train |  8.9471
# val   |  15.1066
#
# [epoch 311] cost time: 9.3559 s
#          loss
# train |  8.8671
# val   |  15.1065
#
# [epoch 312] cost time: 9.5512 s
#          loss
# train |  8.8987
# val   |  15.0365
#
# [epoch 313] cost time: 9.3476 s
#          loss
# train |  8.9599
# val   |  14.8767
#
# [epoch 314] cost time: 9.3456 s
#          loss
# train |  8.8751
# val   |  15.0888
#
# [epoch 315] cost time: 9.3309 s
#          loss
# train |  9.0897
# val   |  15.2433
#
# [epoch 316] cost time: 9.3330 s
#          loss
# train |  9.4589
# val   |  15.0463
#
# [epoch 317] cost time: 9.3439 s
#          loss
# train |  9.3657
# val   |  15.2577
#
# [epoch 318] cost time: 9.5796 s
#          loss
# train |  9.5366
# val   |  15.6321
#
# [epoch 319] cost time: 9.3395 s
#          loss
# train |  9.2447
# val   |  15.1710
#
# [epoch 320] cost time: 9.3175 s
#          loss
# train |  9.2062
# val   |  15.7088
#
# [epoch 321] cost time: 9.3441 s
#          loss
# train |  9.1560
# val   |  15.2840
#
# [epoch 322] cost time: 9.3546 s
#          loss
# train |  9.0884
# val   |  15.3982
#
# [epoch 323] cost time: 9.5595 s
#          loss
# train |  8.9532
# val   |  15.4642
#
# [epoch 324] cost time: 9.3441 s
#          loss
# train |  8.9886
# val   |  15.3745
#
# [epoch 325] cost time: 9.3332 s
#          loss
# train |  8.9705
# val   |  15.1901
#
# [epoch 326] cost time: 9.3443 s
#          loss
# train |  9.2021
# val   |  15.5235
#
# [epoch 327] cost time: 9.3345 s
#          loss
# train |  9.5327
# val   |  15.3128
#
# [epoch 328] cost time: 9.3237 s
#          loss
# train |  9.1823
# val   |  15.5531
#
# [epoch 329] cost time: 9.5526 s
#          loss
# train |  9.0706
# val   |  15.3795
#
# [epoch 330] cost time: 9.3473 s
#          loss
# train |  8.9154
# val   |  15.6847
#
# [epoch 331] cost time: 9.3343 s
#          loss
# train |  8.8333
# val   |  15.8370
#
# [epoch 332] cost time: 9.3383 s
#          loss
# train |  9.0115
# val   |  15.8934
#
# [epoch 333] cost time: 9.3353 s
#          loss
# train |  8.8082
# val   |  16.1912
#
# [epoch 334] cost time: 9.3653 s
#          loss
# train |  8.8446
# val   |  16.2122
#
# [epoch 335] cost time: 9.6393 s
#          loss
# train |  8.7716
# val   |  16.5505
#
# [epoch 336] cost time: 9.3303 s
#          loss
# train |  8.8240
# val   |  16.4526
#
# [epoch 337] cost time: 9.3138 s
#          loss
# train |  8.8484
# val   |  16.7017
#
# [epoch 338] cost time: 9.3087 s
#          loss
# train |  8.7988
# val   |  16.4250
#
# [epoch 339] cost time: 9.3392 s
#          loss
# train |  8.7455
# val   |  16.8201
#
# [epoch 340] cost time: 9.3308 s
#          loss
# train |  8.7793
# val   |  17.0580
#
# [epoch 341] cost time: 9.5437 s
#          loss
# train |  8.7809
# val   |  17.2095
#
# [epoch 342] cost time: 9.3230 s
#          loss
# train |  8.7516
# val   |  17.0018
#
# [epoch 343] cost time: 9.3490 s
#          loss
# train |  8.6769
# val   |  17.2767
#
# [epoch 344] cost time: 9.3231 s
#          loss
# train |  8.6357
# val   |  17.2098
#
# [epoch 345] cost time: 9.3107 s
#          loss
# train |  8.6726
# val   |  17.1638
#
# [epoch 346] cost time: 9.5668 s
#          loss
# train |  8.7378
# val   |  16.8238
#
# [epoch 347] cost time: 9.3284 s
#          loss
# train |  8.7863
# val   |  17.5866
#
# [epoch 348] cost time: 9.3394 s
#          loss
# train |  8.8405
# val   |  16.7600
#
# [epoch 349] cost time: 9.3209 s
#          loss
# train |  8.6952
# val   |  17.2582
#
# [epoch 350] cost time: 9.3166 s
#          loss
# train |  8.9149
# val   |  16.7652
#
# [epoch 351] cost time: 9.3356 s
#          loss
# train |  8.7374
# val   |  17.2542
#
# [epoch 352] cost time: 9.5554 s
#          loss
# train |  8.7113
# val   |  17.0103
#
# [epoch 353] cost time: 9.3427 s
#          loss
# train |  8.7414
# val   |  17.1832
#
# [epoch 354] cost time: 9.3396 s
#          loss
# train |  8.7555
# val   |  16.9885
#
# [epoch 355] cost time: 9.3435 s
#          loss
# train |  8.7912
# val   |  17.1162
#
# [epoch 356] cost time: 9.3251 s
#          loss
# train |  8.5765
# val   |  17.2127
#
# [epoch 357] cost time: 9.3247 s
#          loss
# train |  8.7112
# val   |  16.8369
#
# [epoch 358] cost time: 9.5634 s
#          loss
# train |  8.8959
# val   |  17.4231
#
# [epoch 359] cost time: 9.3323 s
#          loss
# train |  8.6751
# val   |  16.9118
#
# [epoch 360] cost time: 9.3388 s
#          loss
# train |  8.7677
# val   |  17.5528
#
# [epoch 361] cost time: 9.3303 s
#          loss
# train |  8.7096
# val   |  17.2866
#
# [epoch 362] cost time: 9.3481 s
#          loss
# train |  8.6084
# val   |  17.5404
#
# [epoch 363] cost time: 9.3475 s
#          loss
# train |  8.5882
# val   |  17.4124
#
# [epoch 364] cost time: 9.6045 s
#          loss
# train |  8.6570
# val   |  17.9401
#
# [epoch 365] cost time: 9.3558 s
#          loss
# train |  8.5894
# val   |  17.5976
#
# [epoch 366] cost time: 9.3643 s
#          loss
# train |  8.6066
# val   |  17.6953
#
# [epoch 367] cost time: 9.3453 s
#          loss
# train |  8.5344
# val   |  17.8161
#
# [epoch 368] cost time: 9.3425 s
#          loss
# train |  8.9892
# val   |  17.6329
#
# [epoch 369] cost time: 9.3386 s
#          loss
# train |  9.1072
# val   |  17.9815
#
# [epoch 370] cost time: 9.5614 s
#          loss
# train |  8.7467
# val   |  17.7677
#
# [epoch 371] cost time: 9.3328 s
#          loss
# train |  8.7070
# val   |  17.7349
#
# [epoch 372] cost time: 9.3376 s
#          loss
# train |  8.5949
# val   |  17.9528
#
# [epoch 373] cost time: 9.3220 s
#          loss
# train |  8.7804
# val   |  17.5398
#
# [epoch 374] cost time: 9.3668 s
#          loss
# train |  8.7819
# val   |  18.3064
#
# [epoch 375] cost time: 9.5422 s
#          loss
# train |  8.6156
# val   |  17.9743
#
# [epoch 376] cost time: 9.3289 s
#          loss
# train |  8.5382
# val   |  18.2151
#
# [epoch 377] cost time: 9.3166 s
#          loss
# train |  8.4857
# val   |  17.7453
#
# [epoch 378] cost time: 9.3435 s
#          loss
# train |  8.4740
# val   |  17.6503
#
# [epoch 379] cost time: 9.3306 s
#          loss
# train |  8.4959
# val   |  17.1973
#
# [epoch 380] cost time: 9.3269 s
#          loss
# train |  8.6863
# val   |  17.8021
#
# [epoch 381] cost time: 9.5360 s
#          loss
# train |  8.5022
# val   |  17.3849
#
# [epoch 382] cost time: 9.3173 s
#          loss
# train |  8.5463
# val   |  17.3288
#
# [epoch 383] cost time: 9.3317 s
#          loss
# train |  8.4903
# val   |  17.9271
#
# [epoch 384] cost time: 9.3719 s
#          loss
# train |  8.4475
# val   |  18.2315
#
# [epoch 385] cost time: 9.3256 s
#          loss
# train |  8.5961
# val   |  17.2079
#
# [epoch 386] cost time: 9.3035 s
#          loss
# train |  8.5242
# val   |  17.8817
#
# [epoch 387] cost time: 9.5363 s
#          loss
# train |  8.3307
# val   |  18.0001
#
# [epoch 388] cost time: 9.3236 s
#          loss
# train |  8.5674
# val   |  16.8859
#
# [epoch 389] cost time: 9.4240 s
#          loss
# train |  8.6185
# val   |  18.1718
#
# [epoch 390] cost time: 9.3668 s
#          loss
# train |  8.3599
# val   |  18.2278
#
# [epoch 391] cost time: 9.3252 s
#          loss
# train |  8.4577
# val   |  17.4428
#
# [epoch 392] cost time: 9.4232 s
#          loss
# train |  8.4870
# val   |  18.3917
#
# [epoch 393] cost time: 9.5659 s
#          loss
# train |  8.4202
# val   |  17.6185
